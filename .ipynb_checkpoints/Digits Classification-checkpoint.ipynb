# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 import tensorflow as tf
#       2 from tensorflow import keras
#       3 import matplotlib.pyplot as plt
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\__init__.py:473, in <module>
#     471 if hasattr(_current_module, "keras"):
#     472   try:
# --> 473     keras._load()
#     474   except ImportError:
#     475     pass
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\util\lazy_loader.py:41, in LazyLoader._load(self)
#      39 """Load the module and insert it into the parent's globals."""
#      40 # Import the target module and insert it into the parent's namespace
# ---> 41 module = importlib.import_module(self.__name__)
#      42 self._parent_module_globals[self._local_name] = module
#      44 # Emit a warning if one was specified
#
# File ~\AppData\Local\Programs\Python\Python310\lib\importlib\__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\__init__.py:24, in <module>
#      21 from tensorflow.python import tf2
#      22 from keras import distribute
# ---> 24 from keras import models
#      26 from keras.engine.input_layer import Input
#      27 from keras.engine.sequential import Sequential
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\models\__init__.py:18, in <module>
#      15 """Keras models API."""
#      16 # pylint: disable=g-bad-import-order
# ---> 18 from keras.engine.functional import Functional
#      19 from keras.engine.sequential import Sequential
#      20 from keras.engine.training import Model
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\engine\functional.py:31, in <module>
#      29 from keras.engine import input_spec
#      30 from keras.engine import node as node_module
# ---> 31 from keras.engine import training as training_lib
#      32 from keras.engine import training_utils
#      33 from keras.saving.saved_model import json_utils
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\engine\training.py:30, in <module>
#      28 from keras.engine import base_layer
#      29 from keras.engine import base_layer_utils
# ---> 30 from keras.engine import compile_utils
#      31 from keras.engine import data_adapter
#      32 from keras.engine import input_layer as input_layer_module
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\engine\compile_utils.py:20, in <module>
#      18 import copy
#      19 from keras import losses as losses_mod
# ---> 20 from keras import metrics as metrics_mod
#      21 from keras.utils import generic_utils
#      22 from keras.utils import losses_utils
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\metrics\__init__.py:33, in <module>
#      30 from keras.metrics.base_metric import SumOverBatchSizeMetricWrapper
#      32 # Individual metric classes
# ---> 33 from keras.metrics.metrics import MeanRelativeError
#      34 from keras.metrics.metrics import Accuracy
#      35 from keras.metrics.metrics import BinaryAccuracy
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\metrics\metrics.py:22, in <module>
#      19 import abc
#      20 from typing import List, Tuple, Union
# ---> 22 from keras import activations
#      23 from keras import backend
#      24 from keras.dtensor import utils as dtensor_utils
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\activations.py:20, in <module>
#      17 import tensorflow.compat.v2 as tf
#      19 from keras import backend
# ---> 20 import keras.layers.activation as activation_layers
#      21 from keras.utils.generic_utils import deserialize_keras_object
#      22 from keras.utils.generic_utils import serialize_keras_object
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\layers\__init__.py:27, in <module>
#      25 from keras.engine.input_spec import InputSpec
#      26 from keras.engine.base_layer import Layer
# ---> 27 from keras.engine.base_preprocessing_layer import PreprocessingLayer
#      29 # Image preprocessing layers.
#      30 from keras.layers.preprocessing.image_preprocessing import CenterCrop
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\engine\base_preprocessing_layer.py:19, in <module>
#      15 """Contains the base ProcessingLayer and a subclass that uses Combiners."""
#      17 import abc
# ---> 19 from keras.engine import data_adapter
#      20 from keras.engine.base_layer import Layer
#      21 from keras.utils import version_utils
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\engine\data_adapter.py:38, in <module>
#      35 from tensorflow.python.util.tf_export import keras_export
#      37 try:
# ---> 38   import pandas as pd  # pylint: disable=g-import-not-at-top
#      39 except ImportError:
#      40   pd = None
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\__init__.py:135, in <module>
#     117 from pandas.core.computation.api import eval
#     119 from pandas.core.reshape.api import (
#     120     concat,
#     121     lreshape,
#    (...)
#     132     qcut,
#     133 )
# --> 135 from pandas import api, arrays, errors, io, plotting, testing, tseries
#     136 from pandas.util._print_versions import show_versions
#     138 from pandas.io.api import (
#     139     # excel
#     140     ExcelFile,
#    (...)
#     168     read_spss,
#     169 )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\testing.py:6, in <module>
#       1 """
#       2 Public testing utility functions.
#       3 """
# ----> 6 from pandas._testing import (
#       7     assert_extension_array_equal,
#       8     assert_frame_equal,
#       9     assert_index_equal,
#      10     assert_series_equal,
#      11 )
#      13 __all__ = [
#      14     "assert_extension_array_equal",
#      15     "assert_frame_equal",
#      16     "assert_series_equal",
#      17     "assert_index_equal",
#      18 ]
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_testing\__init__.py:979, in <module>
#     974     import pytest
#     976     return pytest.raises(expected_exception, match=None)  # noqa: PDF010
# --> 979 cython_table = pd.core.common._cython_table.items()
#     982 def get_cython_table_params(ndframe, func_names_and_expected):
#     983     """
#     984     Combine frame, functions from com._cython_table
#     985     keys and expected result.
#    (...)
#     997         List of three items (DataFrame, function, expected result)
#     998     """
#
# AttributeError: partially initialized module 'pandas' has no attribute 'core' (most likely due to a circular import)

# %%
(x_train,y_train),(x_test,y_test) = keras.datasets.mnist.load_data()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 (x_train,y_train),(x_test,y_test) = keras.datasets.mnist.load_data()
#
# NameError: name 'keras' is not defined
